# %% [markdown]
# # Data Analysis Project

# %% [markdown]
# * Take **Problem statement**-Understand problem statement
# * **Download data** (hotel bookings)
# * **Identify data**
# * **Clean data**-Explore Data (columns in the dataset , that match out requirements)- see values ,variables, data types
#
# **Based on Problem Question**
# * **Analyse Data** and Find useful insights
# (problem statement includes formulating Research question And Hypothesis)
# Research Q- What we are going to find from data
# Hypo-Assumptions(During analysis this ans will be of that question, etc.)
# After Analysis We come to know that this Hypo is True or False
#
# * **Data Visualization** (Present Data using Report or Dashboards)
#
# Conclusion (Suggestion)

# %% [markdown]
# ## Bussiness Problem
#
# - A Hotel company comes to us and says,there are high cancelation rates,
#
# (as there is cancellation, revenue decreses , and rooms are also ideal, lot of money is spend on room services,etc.)
# because of this they are facing loss.
#
# - What we have to do ??
#
# Understand their problem , collect relavant data,
#
# Cancelation is the main problem , why it is happening , what suggestion can e give to them
# focusing on factors affecting the cancelation,
# and things which are waste to hotels ( so that hotels do not have to pay more attention on them)

# %% [markdown]
# ## Assumptions
#
# - Kaggle Data Have outliers , but we assumed that there are not outliers, if you feel you can remove it
#
# - If data is old, still we assume data is current
#
# - Suggestions given to hotel must be taken in a positive way (feedback)
#
# - Room Cancelation is the major problem affecting the revenue loss

# %% [markdown]
# ## Research Question ( we have to find for Problem Questions)
#
# - Variables that affect Hotel Reservation Cancelation (important features)
#
# - Making Pricing Decisions and Reservation Better

# %% [markdown]
# ## Hypothesis
#
# - Assume that cancelation increase when Prices are high
#
# - Long Waiting List then Cancelation Occur

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load data

# %%
#The Data We can from an organization will not be of Customer private data (name,address, etc,)--
#so remove it(this data do not have that columns)
dataset=pd.read_csv('hotel_bookings 2.csv')
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# - Descriptive Statistics
# - Univariate Analysis
# - Bivariate Analysis
# - Multivariate Analysis
# - Data Cleaning
# - Visualization
# - Dimensionality Reduction
# - Pattern Recognition

# %%
dataset.shape
# Out:
# (119390, 32)

# %%
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Change DataType of Required Column ( data --> from object to dateime)

dataset['reservation_status_date']=pd.to_datetime(dataset['reservation_status_date']) 
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
#Describe for objective column
#But if we use below code, it will give summary about object only

dataset.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
dataset.describe(include='object').columns
# Out:
# Index(['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment',
#        'distribution_channel', 'reserved_room_type', 'assigned_room_type',
#        'deposit_type', 'customer_type', 'reservation_status'],
#       dtype='object')

# %%
print('Hotel Column  Unique Values : ',dataset['hotel'].unique())
print()
print('Country Column  Unique Values : ',dataset['country'].unique())
# Out:
# Hotel Column  Unique Values :  ['Resort Hotel' 'City Hotel']
#
# Country Column  Unique Values :  ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
#  'NPL' 'BHS' 'MAC' 'TGO' 'TWN' 'DJI' 'STP' 'KNA' 'ETH' 'IRQ' 'HND' 'RWA'
#  'KHM' 'MCO' 'BGD' 'IMN' 'TJK' 'NIC' 'BEN' 'VGB' 'TZA' 'GAB' 'GHA' 'TMP'
# ...

# %%
#Instead of doing it for all columns one by one , we will make a 'for loop'

for col in dataset.describe(include='object').columns:
    print(col)
    print(dataset[col].unique())
    print()
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
#
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# agent & company have many null values , so remove that column
# children & country have less null values , so remove that null values rows

dataset.drop(['agent','company'],axis=1,inplace=True)  #remove columns
dataset.dropna(inplace=True)   #remove rows

dataset.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
#Describe for Numerical Columns

dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#There are many outliers
#use box plot and see

dataset['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Slicing 'adr' column

# %%
#here only one value is far away , so remove it in adr column
#other columns also have outlier values , you can remove it

dataset=dataset[dataset['adr']<500]  #take and specific set of values you want

# %%
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118895.000000  118895.000000      118895.000000
# mean        0.371353     104.313764        2016.157660
# std         0.483169     106.903621           0.707456
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118895.000000              118895.000000
# mean                  27.166727                  15.800866
# std                   13.590058                   8.780372
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
dataset['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Analyse Clean Data

# %% [markdown]
# ### Reservations that are canceled / not canceled

# %%
cancelled_percent=dataset['is_canceled'].value_counts()
cancelled_percent
# Out:
# 0    74743
# 1    44152
# Name: is_canceled, dtype: int64

# %%
cancelled_percent=dataset['is_canceled'].value_counts(normalize=True)   #for value in percent
cancelled_percent
# Out:
# 0    0.628647
# 1    0.371353
# Name: is_canceled, dtype: float64

# %%
#Visualze

plt.figure(figsize=(7,5))
plt.title('Reservation Status Count')
plt.bar(['Not Cancelled','Cancelled'],dataset['is_canceled'].value_counts(),color='red',edgecolor='k',width=0.3)
plt.show()

#the count of canceled is more , so it is a major issue for hotels

# %% [markdown]
# ### Reservations Canceled or not of Different Hotels

# %%
#Check which Hotels have high & low cancelation rates

plt.figure(figsize=(7,5))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=dataset, palette='PuBuGn')
legend_labels, _ = ax1.get_legend_handles_labels()

# Use Matplotlib's legend function
ax1.legend(legend_labels, ['Not Canceled', 'Canceled'], bbox_to_anchor=(1, 1))

plt.xlabel('HOTEL')
plt.ylabel('Number of Reservations')
plt.show()

# %%
#filter only resort hotel

resort_hotel=dataset[dataset['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
#here the difference is more, which is fine
# Out:
# 0    0.720242
# 1    0.279758
# Name: is_canceled, dtype: float64

# %%
#filter only city hotel
city_hotel=dataset[dataset['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
#here the difference is less, whch is a concern
# Out:
# 0    0.582913
# 1    0.417087
# Name: is_canceled, dtype: float64

# %% [markdown]
# ### Is price affecting the cancelation of bookings in both the hotels or not affecting (Assumption)

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()

#reservation_status_date --> index
#adr--> value (average daily rate)

# %%
resort_hotel.count()
# Out:
# adr    913
# dtype: int64

# %%
city_hotel.count()
# Out:
# adr    864
# dtype: int64

# %%
dataset['hotel'].count()
# Out:
# 118895

# %%
plt.figure(figsize=(18,6))
plt.title('Average Daily Rate in City and Resort Hotel')
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label='City Hotel')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.title('Average Daily Rate in City and Resort Hotel')
plt.scatter(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.scatter(city_hotel.index,city_hotel['adr'],label='City Hotel')
plt.legend()
plt.show()

# %% [markdown]
# **city_hotel is having adr in a low range,
# resort_hotel having adr at high range**
#
# **some are high some are low,
# assuming high(spikes) is for weekends on both the hotels**
#
# **so city_hotel price is less as compared with resort_hotel price for some days,
# Days can be holidays or weekends**

# %% [markdown]
# ### Months Having Reservation and then Cancelation / Not Cancelation

# %%
#Now look at months where there are reservtions and where there are cancelations
#we don't have any month column
#we will make month column using the date column
dataset['Month']=dataset['reservation_status_date'].dt.month


plt.figure(figsize=(12,5))
ax1 = sns.countplot(x='Month', hue='is_canceled', data=dataset, palette='twilight')
legend_labels, _ = ax1.get_legend_handles_labels()

# Use Matplotlib's legend function
ax1.legend(legend_labels, ['Not Canceled', 'Canceled'], bbox_to_anchor=(1, 1))
plt.title('Reservation Status per Month')
plt.xlabel('Months')
plt.ylabel('Number of Reservations')
plt.show()

# %% [markdown]
# ### Cancelation rate Month-wise with respect to 'adr'

# %%
# This is only for cancellation rate
# beacuse we want to check whether price is affecting cancelation or not

plt.figure(figsize=(7,5))
plt.title('ADR per month')
sns.barplot('Month','adr',data=dataset[dataset['is_canceled']==1].groupby('Month')[['adr']].sum().reset_index())
#dataset['is_canceled']==1  means only canceled values
plt.show()

# %% [markdown]
# Our hypo proves that if price is high than cancelation is also high
# They do reservation(as shown in previous graph of Reservation status) and maybe at last moment they cancel it

# %% [markdown]
# ### Cancelation Rate - country wise

# %%
#only see top 10 countries , as there are 177 countries in data

cancelled_data=dataset[dataset['is_canceled']==1]
top_10_countries=cancelled_data['country'].value_counts()[:10]  #sort in decending
#value_counts means how many times the value is coming in that column

plt.figure(figsize=(8,8))

plt.title('Top 10 Countries with Reservation Cancelled')

plt.pie(top_10_countries,autopct='%.2f',labels=top_10_countries.index)
#autopct='%.2f' values upto 2 decimals
plt.show()

# %% [markdown]
# There are many cancelations in Portugal,
# So we suggest them that they should increase facilities in Portugal Hotels, proper price , advertisement, etc.

# %% [markdown]
# ### Clients coming from which Travel Agents
# online travel agent, offline travel agent, etc

# %%
dataset['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24158
# Groups           19806
# Direct           12448
# Corporate         5110
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
#percentage count
dataset['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474385
# Offline TA/TO    0.203188
# Groups           0.166584
# Direct           0.104697
# Corporate        0.042979
# Complementary    0.006174
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %% [markdown]
# **Our hypo is wrong here, Our hypo was that offline send more clients to hotels**

# %% [markdown]
# ### Cancelation Data wrt Market Segment

# %%
# we will see only for canceled data

cancelled_data['market_segment'].value_counts(normalize=True)  #no offline cancel
#there are more online reservation but still more number of them is cancelled
#the reason might be , online photos are good, but in actual there might be not so good

#the hotels have to show what reality is, do not over-exaggeration
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %% [markdown]
# ### Cancelation And Not Cancelation mean wrt adr

# %%
# cancelled_data=dataset[dataset['is_canceled']==1]
not_cancelled_data=dataset[dataset['is_canceled']==0]

# %%
cancelled_dataset_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_dataset_adr.reset_index(inplace=True)
cancelled_dataset_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_dataset_adr=not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_dataset_adr.reset_index(inplace=True)
not_cancelled_dataset_adr.sort_values('reservation_status_date',inplace=True)

# %%
plt.figure(figsize=(18,7))
plt.plot(cancelled_dataset_adr['reservation_status_date'],cancelled_dataset_adr['adr'],label='Cancelled')
plt.plot(not_cancelled_dataset_adr['reservation_status_date'],not_cancelled_dataset_adr['adr'],label='Not Cancelled')
plt.title('Average Daily Rate')
plt.legend()
plt.show()

# %% [markdown]
# **cancelled reservation mean is high, or not canceled reservation mean is high**

# %%
plt.figure(figsize=(18,7))
plt.scatter(cancelled_dataset_adr['reservation_status_date'],cancelled_dataset_adr['adr'],label='Cancelled')
plt.scatter(not_cancelled_dataset_adr['reservation_status_date'],not_cancelled_dataset_adr['adr'],label='Not Cancelled')
plt.title('Average Daily Rate')
plt.legend()
plt.show()

# %% [markdown]
# **We have more data in middle , less at start and end**
#
# **There is in-consistency in dataset**
#
# **We will remove it by taking specific range***
#
# **Take only 2016-01 to 2017-09 data**

# %% [markdown]
# ### Taking Data from specific Range

# %%
cancelled_dataset_adr=cancelled_dataset_adr[(cancelled_dataset_adr['reservation_status_date']>'2016-01') 
                                            & (cancelled_dataset_adr['reservation_status_date']<'2017-09')]


not_cancelled_dataset_adr=not_cancelled_dataset_adr[(not_cancelled_dataset_adr['reservation_status_date']>'2016-01') 
                                                    & (not_cancelled_dataset_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(18,7))
plt.plot(cancelled_dataset_adr['reservation_status_date'],cancelled_dataset_adr['adr'],label='Cancelled')
plt.plot(not_cancelled_dataset_adr['reservation_status_date'],not_cancelled_dataset_adr['adr'],label='Not Cancelled')
plt.title('Average Daily Rate',fontsize=18)
plt.legend(fontsize=18)
plt.show()

# %% [markdown]
# **Avg Daily rate of canceled is more than AVg Daily rate of not cancelled**
#
# **Proof --> Cancellation depends on Price**
#
# **Spikes are nothing but weekend or holidays**

# %% [markdown]
# - Make a Report, of whatever we had did till now, with short summary, (storytelling)

# %% [markdown]
# ## Suggestions

# %% [markdown]
# - Cancelation Increase as Price Increase,Hotels sjould work on their pricing strategyand try tomlower ratesof specific hotels based on locations. Discounts can also be provided
#
# - Ratio of Cancelation and Not Cancelation is higher in resort hotel than incity hotel
#
# - In jan Hotels can start marketing to increase their revenue as cancelation is highest in this month
#
# - Increase Quality of Hotel and Services Mainly in Portugal to reduce cancelation rate
